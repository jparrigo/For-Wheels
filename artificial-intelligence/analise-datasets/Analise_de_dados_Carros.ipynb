# %%
import pandas as pd
import numpy as np
df_car = pd.read_csv("../datasets/cars/data.csv", sep=",", header=0)
df_car.head()
# Out:
#   Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0
# 2  BMW    1 Series  2011  premium unleaded (required)      300.0
# 3  BMW    1 Series  2011  premium unleaded (required)      230.0
# 4  BMW    1 Series  2011  premium unleaded (required)      230.0
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 0               6.0            MANUAL  rear wheel drive                2
# 1               6.0            MANUAL  rear wheel drive                2
# 2               6.0            MANUAL  rear wheel drive                2
# 3               6.0            MANUAL  rear wheel drive                2
# 4               6.0            MANUAL  rear wheel drive                2
#
#                          Market Category Vehicle Size Vehicle Style  \
# ...

# %%
df_car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11914 entries, 0 to 11913
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Make               11914 non-null  object
#  1   Model              11914 non-null  object
#  2   Year               11914 non-null  int64
#  3   Engine Fuel Type   11911 non-null  object
#  4   Engine HP          11845 non-null  float64
#  5   Engine Cylinders   11911 non-null  float64
#  6   Transmission Type  11914 non-null  object
#  7   Driven_Wheels      11914 non-null  object
#  8   Number of Doors    11914 non-null  int64
#  9   Market Category    8172 non-null   object
#  10  Vehicle Size       11914 non-null  object
#  11  Vehicle Style      11914 non-null  object
#  12  highway MPG        11914 non-null  int64
#  13  city mpg           11914 non-null  int64
#  14  Popularity         11914 non-null  int64
#  15  MSRP               11914 non-null  int64
# ...

# %%
brands = ["Saab", "Scion"]
minYear = 2010
gasoline_fuel = ["gasoline", "regular unleaded", "premium unleaded (required)", "premium unleaded (recommended)"]
flex_fuel = ["flex-fuel", "flex-fuel (unleaded/E85)", "flex-fuel (premium unleaded required/E85)", "flex-fuel (premium unleaded recommended/E85)"]
natGas = ["natural gas", "flex-fuel (unleaded/natural gas)"]
suv = ["SUV", "4dr SUV", "2dr SUV", "Convertible SUV"]
hatchback = ["Hatchback", "4dr Hatchback", "2dr Hatchback"]
pickup = ["Pickup", "Crew Cab Pickup", "Extended Cab Pickup", "Regular Cab Pickup"]
minivan = ["Minivan", "Passenger Minivan", "Cargo Minivan"]
fwd = ["front wheel drive", "FWD"]
rwd = ["rear wheel drive", "RWD"]
awd = ["all wheel drive", "AWD"]
fourwd = ["four wheel drive", "4WD"]
three_dr = 3
df_car = df_car.where(df_car["Make"] != brands[0])
df_car = df_car.where(df_car["Make"] != brands[1])
df_car = df_car.where(df_car["Year"] >= minYear)
df_car = df_car.where(df_car["Engine Fuel Type"] != natGas[0])
df_car = df_car.where(df_car["Engine Fuel Type"] != natGas[1])
df_car = df_car.where(df_car["Number of Doors"] != three_dr)
df_car["Engine Fuel Type"] = np.where(df_car["Engine Fuel Type"] == gasoline_fuel[1], gasoline_fuel[0], df_car["Engine Fuel Type"])
df_car["Engine Fuel Type"] = np.where(df_car["Engine Fuel Type"] == gasoline_fuel[2], gasoline_fuel[0], df_car["Engine Fuel Type"])
df_car["Engine Fuel Type"] = np.where(df_car["Engine Fuel Type"] == gasoline_fuel[3], gasoline_fuel[0], df_car["Engine Fuel Type"])
df_car["Engine Fuel Type"] = np.where(df_car["Engine Fuel Type"] == flex_fuel[1], flex_fuel[0], df_car["Engine Fuel Type"])
df_car["Engine Fuel Type"] = np.where(df_car["Engine Fuel Type"] == flex_fuel[2], flex_fuel[0], df_car["Engine Fuel Type"])
df_car["Engine Fuel Type"] = np.where(df_car["Engine Fuel Type"] == flex_fuel[3], flex_fuel[0], df_car["Engine Fuel Type"])
df_car["Vehicle Style"] = np.where(df_car["Vehicle Style"] == suv[1], suv[0], df_car["Vehicle Style"])
df_car["Vehicle Style"] = np.where(df_car["Vehicle Style"] == suv[2], suv[0], df_car["Vehicle Style"])
df_car["Vehicle Style"] = np.where(df_car["Vehicle Style"] == suv[3], suv[0], df_car["Vehicle Style"])
df_car["Vehicle Style"] = np.where(df_car["Vehicle Style"] == hatchback[1], hatchback[0], df_car["Vehicle Style"])
df_car["Vehicle Style"] = np.where(df_car["Vehicle Style"] == hatchback[2], hatchback[0], df_car["Vehicle Style"])
df_car["Vehicle Style"] = np.where(df_car["Vehicle Style"] == pickup[1], pickup[0], df_car["Vehicle Style"])
df_car["Vehicle Style"] = np.where(df_car["Vehicle Style"] == pickup[2], pickup[0], df_car["Vehicle Style"])
df_car["Vehicle Style"] = np.where(df_car["Vehicle Style"] == pickup[3], pickup[0], df_car["Vehicle Style"])
df_car["Vehicle Style"] = np.where(df_car["Vehicle Style"] == minivan[1], minivan[0], df_car["Vehicle Style"])
df_car["Vehicle Style"] = np.where(df_car["Vehicle Style"] == minivan[2], minivan[0], df_car["Vehicle Style"])
df_car["Driven_Wheels"] = np.where(df_car["Driven_Wheels"] == fwd[0], fwd[1], df_car["Driven_Wheels"])
df_car["Driven_Wheels"] = np.where(df_car["Driven_Wheels"] == rwd[0], rwd[1], df_car["Driven_Wheels"])
df_car["Driven_Wheels"] = np.where(df_car["Driven_Wheels"] == awd[0], awd[1], df_car["Driven_Wheels"])
df_car["Driven_Wheels"] = np.where(df_car["Driven_Wheels"] == fourwd[0], fourwd[1], df_car["Driven_Wheels"])
df_car = df_car.dropna(axis=0, how="all")
df_car = df_car.reset_index()
df_car.drop("index", axis=1, inplace=True)
df_car.head()
# Out:
#   Make       Model    Year Engine Fuel Type  Engine HP  Engine Cylinders  \
# 0  BMW  1 Series M  2011.0         gasoline      335.0               6.0
# 1  BMW    1 Series  2011.0         gasoline      300.0               6.0
# 2  BMW    1 Series  2011.0         gasoline      300.0               6.0
# 3  BMW    1 Series  2011.0         gasoline      230.0               6.0
# 4  BMW    1 Series  2011.0         gasoline      230.0               6.0
#
#   Transmission Type Driven_Wheels  Number of Doors  \
# 0            MANUAL           RWD              2.0
# 1            MANUAL           RWD              2.0
# 2            MANUAL           RWD              2.0
# 3            MANUAL           RWD              2.0
# 4            MANUAL           RWD              2.0
#
#                          Market Category Vehicle Size Vehicle Style  \
# 0  Factory Tuner,Luxury,High-Performance      Compact         Coupe
# 1                     Luxury,Performance      Compact   Convertible
# ...

# %%
df_car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7647 entries, 0 to 7646
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Make               7647 non-null   object
#  1   Model              7647 non-null   object
#  2   Year               7647 non-null   float64
#  3   Engine Fuel Type   7647 non-null   object
#  4   Engine HP          7590 non-null   float64
#  5   Engine Cylinders   7647 non-null   float64
#  6   Transmission Type  7647 non-null   object
#  7   Driven_Wheels      7647 non-null   object
#  8   Number of Doors    7647 non-null   float64
#  9   Market Category    6019 non-null   object
#  10  Vehicle Size       7647 non-null   object
#  11  Vehicle Style      7647 non-null   object
#  12  highway MPG        7647 non-null   float64
#  13  city mpg           7647 non-null   float64
#  14  Popularity         7647 non-null   float64
# ...

# %%
df_car["Market Category"] = df_car["Market Category"].fillna("Common")
df_car.head()
# Out:
#   Make       Model    Year Engine Fuel Type  Engine HP  Engine Cylinders  \
# 0  BMW  1 Series M  2011.0         gasoline      335.0               6.0
# 1  BMW    1 Series  2011.0         gasoline      300.0               6.0
# 2  BMW    1 Series  2011.0         gasoline      300.0               6.0
# 3  BMW    1 Series  2011.0         gasoline      230.0               6.0
# 4  BMW    1 Series  2011.0         gasoline      230.0               6.0
#
#   Transmission Type Driven_Wheels  Number of Doors  \
# 0            MANUAL           RWD              2.0
# 1            MANUAL           RWD              2.0
# 2            MANUAL           RWD              2.0
# 3            MANUAL           RWD              2.0
# 4            MANUAL           RWD              2.0
#
#                          Market Category Vehicle Size Vehicle Style  \
# 0  Factory Tuner,Luxury,High-Performance      Compact         Coupe
# 1                     Luxury,Performance      Compact   Convertible
# ...

# %%
temp = df_car
temp[["Category 1", "Category 2", "Category 3", "Category 4", "Category 5"]] = df_car["Market Category"].str.split(",", expand=True)
temp.head()
# Out:
#   Make       Model    Year Engine Fuel Type  Engine HP  Engine Cylinders  \
# 0  BMW  1 Series M  2011.0         gasoline      335.0               6.0
# 1  BMW    1 Series  2011.0         gasoline      300.0               6.0
# 2  BMW    1 Series  2011.0         gasoline      300.0               6.0
# 3  BMW    1 Series  2011.0         gasoline      230.0               6.0
# 4  BMW    1 Series  2011.0         gasoline      230.0               6.0
#
#   Transmission Type Driven_Wheels  Number of Doors  \
# 0            MANUAL           RWD              2.0
# 1            MANUAL           RWD              2.0
# 2            MANUAL           RWD              2.0
# 3            MANUAL           RWD              2.0
# 4            MANUAL           RWD              2.0
#
#                          Market Category  ... Vehicle Style highway MPG  \
# 0  Factory Tuner,Luxury,High-Performance  ...         Coupe        26.0
# ...

# %%
temp_dummy1 = pd.get_dummies(temp["Category 1"])
temp_dummy2 = pd.get_dummies(temp["Category 2"])
temp_dummy3 = pd.get_dummies(temp["Category 3"])
temp_dummy4 = pd.get_dummies(temp["Category 4"])
temp_dummy5 = pd.get_dummies(temp["Category 5"])

# %%
temp_dummy1 = temp_dummy1.reindex(sorted(temp_dummy1.columns), axis=1)
temp_dummy2 = temp_dummy2.reindex(sorted(temp_dummy1.columns), axis=1)
temp_dummy3 = temp_dummy3.reindex(sorted(temp_dummy1.columns), axis=1)
temp_dummy4 = temp_dummy4.reindex(sorted(temp_dummy1.columns), axis=1)
temp_dummy5 = temp_dummy5.reindex(sorted(temp_dummy1.columns), axis=1)

# %%
category_dummy = temp_dummy1 | temp_dummy2 | temp_dummy3 | temp_dummy4 | temp_dummy5
category_dummy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7647 entries, 0 to 7646
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Common            7647 non-null   bool
#  1   Crossover         7647 non-null   bool
#  2   Diesel            7647 non-null   bool
#  3   Exotic            7647 non-null   bool
#  4   Factory Tuner     7647 non-null   bool
#  5   Flex Fuel         7647 non-null   bool
#  6   Hatchback         7647 non-null   bool
#  7   High-Performance  7647 non-null   bool
#  8   Hybrid            7647 non-null   bool
#  9   Luxury            7647 non-null   bool
#  10  Performance       7647 non-null   bool
# dtypes: bool(11)
# memory usage: 82.3 KB

# %%
old_df_car = df_car
df_car = pd.concat([old_df_car.drop("Market Category", axis=1), category_dummy], axis=1)
df_car = df_car.drop(["Category 1", "Category 2", "Category 3", "Category 4", "Category 5", "Diesel", "Flex Fuel"], axis=1)
display(df_car)
# Out:
#        Make       Model    Year Engine Fuel Type  Engine HP  Engine Cylinders  \
# 0       BMW  1 Series M  2011.0         gasoline      335.0               6.0
# 1       BMW    1 Series  2011.0         gasoline      300.0               6.0
# 2       BMW    1 Series  2011.0         gasoline      300.0               6.0
# 3       BMW    1 Series  2011.0         gasoline      230.0               6.0
# 4       BMW    1 Series  2011.0         gasoline      230.0               6.0
# ...     ...         ...     ...              ...        ...               ...
# 7642  Acura         ZDX  2011.0         gasoline      300.0               6.0
# 7643  Acura         ZDX  2012.0         gasoline      300.0               6.0
# 7644  Acura         ZDX  2012.0         gasoline      300.0               6.0
# 7645  Acura         ZDX  2012.0         gasoline      300.0               6.0
# 7646  Acura         ZDX  2013.0         gasoline      300.0               6.0
#
# ...

# %%
df_car[df_car["Engine HP"].isna()]
# Out:
#                Make        Model    Year Engine Fuel Type  Engine HP  \
# 355            FIAT         500e  2015.0         electric        NaN
# 356            FIAT         500e  2016.0         electric        NaN
# 357            FIAT         500e  2017.0         electric        NaN
# 1810        Lincoln  Continental  2017.0         gasoline        NaN
# 1811        Lincoln  Continental  2017.0         gasoline        NaN
# 1812        Lincoln  Continental  2017.0         gasoline        NaN
# 1813        Lincoln  Continental  2017.0         gasoline        NaN
# 2731           Ford       Escape  2017.0         gasoline        NaN
# 2732           Ford       Escape  2017.0         gasoline        NaN
# 2733           Ford       Escape  2017.0         gasoline        NaN
# 2734           Ford       Escape  2017.0         gasoline        NaN
# 2984          Honda       Fit EV  2013.0         electric        NaN
# 2985          Honda       Fit EV  2014.0         electric        NaN
# ...

# %%
# df_car = df_car.astype({"Engine HP": 'int64'})
df_car = df_car.astype({"Year": 'int64', "Engine Cylinders": 'int64', "Number of Doors": 'int64', "highway MPG": 'int64', "city mpg": 'int64', "Popularity": 'int64', "MSRP": 'int64'})
# df_car["Vehicle_Title_Partial"] = df_car["Year"].astype(str) + " " + df_car["Make"].astype(str) + " " + df_car["Model"].astype(str)
df_car["Vehicle_Title_Partial"] = df_car["Year"].astype(str) + " " + df_car["Make"].astype(str) + " " + df_car["Model"].astype(str) + " " + df_car["Number of Doors"].astype(str) + "dr " + df_car["Vehicle Style"] + " " + df_car["Driven_Wheels"] + " (" + df_car["Engine Cylinders"].astype(str) + "cyl)"

# %%
df_car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7647 entries, 0 to 7646
# Data columns (total 25 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Make                   7647 non-null   object
#  1   Model                  7647 non-null   object
#  2   Year                   7647 non-null   int64
#  3   Engine Fuel Type       7647 non-null   object
#  4   Engine HP              7590 non-null   float64
#  5   Engine Cylinders       7647 non-null   int64
#  6   Transmission Type      7647 non-null   object
#  7   Driven_Wheels          7647 non-null   object
#  8   Number of Doors        7647 non-null   int64
#  9   Vehicle Size           7647 non-null   object
#  10  Vehicle Style          7647 non-null   object
#  11  highway MPG            7647 non-null   int64
#  12  city mpg               7647 non-null   int64
#  13  Popularity             7647 non-null   int64
# ...

# %%
df_car["Make"].value_counts()
# Out:
# Make
# Volkswagen       686
# Chevrolet        646
# Toyota           597
# Ford             452
# Nissan           451
# Honda            388
# Cadillac         338
# BMW              305
# Audi             272
# Mercedes-Benz    264
# GMC              261
# Dodge            256
# Infiniti         236
# Mazda            230
# Hyundai          220
# Subaru           181
# Volvo            177
# Acura            174
# Kia              173
# Lexus            140
# Mitsubishi       130
# Buick            120
# Porsche          120
# Land Rover       115
# Lincoln          112
# Suzuki           106
# Aston Martin      85
# Chrysler          81
# FIAT              62
# Bentley           54
# Maserati          42
# Lamborghini       42
# Rolls-Royce       26
# Ferrari           23
# Lotus             21
# Tesla             18
# Maybach           16
# HUMMER             9
# Pontiac            5
# Alfa Romeo         5
# McLaren            5
# Genesis            3
# ...

# %%
df_car["Year"].value_counts()
# Out:
# Year
# 2015    2115
# 2016    2100
# 2017    1650
# 2014     529
# 2012     353
# 2013     345
# 2010     288
# 2011     267
# Name: count, dtype: int64

# %%
df_car["Engine Fuel Type"].value_counts()
# Out:
# Engine Fuel Type
# gasoline     6715
# flex-fuel     723
# diesel        143
# electric       66
# Name: count, dtype: int64

# %%
df_car["Engine HP"].isna().value_counts()
# Out:
# Engine HP
# False    7590
# True       57
# Name: count, dtype: int64

# %%
df_car["Engine HP"].min()
# Out:
# 66.0

# %%
df_car["Engine HP"].max()
# Out:
# 750.0

# %%
df_car["Engine Cylinders"].value_counts()
# Out:
# Engine Cylinders
# 4     3410
# 6     2584
# 8     1214
# 12     174
# 5      106
# 0       76
# 10      65
# 3       18
# Name: count, dtype: int64

# %%
df_car["Transmission Type"].value_counts()
# Out:
# Transmission Type
# AUTOMATIC           5759
# MANUAL              1254
# AUTOMATED_MANUAL     566
# DIRECT_DRIVE          68
# Name: count, dtype: int64

# %%
df_car["Driven_Wheels"].value_counts()
# Out:
# Driven_Wheels
# FWD    2996
# AWD    1969
# RWD    1859
# 4WD     823
# Name: count, dtype: int64

# %%
df_car["Number of Doors"].value_counts()
# Out:
# Number of Doors
# 4    6059
# 2    1588
# Name: count, dtype: int64

# %%
df_car["Vehicle Size"].value_counts()
# Out:
# Vehicle Size
# Midsize    2987
# Compact    2814
# Large      1846
# Name: count, dtype: int64

# %%
df_car["Vehicle Style"].value_counts()
# Out:
# Vehicle Style
# Sedan          2116
# SUV            1977
# Pickup          970
# Hatchback       797
# Coupe           720
# Convertible     531
# Wagon           311
# Minivan         225
# Name: count, dtype: int64

# %%
df_car.head()
# Out:
#   Make       Model  Year Engine Fuel Type  Engine HP  Engine Cylinders  \
# 0  BMW  1 Series M  2011         gasoline      335.0                 6
# 1  BMW    1 Series  2011         gasoline      300.0                 6
# 2  BMW    1 Series  2011         gasoline      300.0                 6
# 3  BMW    1 Series  2011         gasoline      230.0                 6
# 4  BMW    1 Series  2011         gasoline      230.0                 6
#
#   Transmission Type Driven_Wheels  Number of Doors Vehicle Size  ... Common  \
# 0            MANUAL           RWD                2      Compact  ...  False
# 1            MANUAL           RWD                2      Compact  ...  False
# 2            MANUAL           RWD                2      Compact  ...  False
# 3            MANUAL           RWD                2      Compact  ...  False
# 4            MANUAL           RWD                2      Compact  ...  False
#
#    Crossover  Exotic  Factory Tuner  Hatchback  High-Performance  Hybrid  \
# ...

# %%
df_car.to_csv("../datasets/cars/cars_dataset.csv", sep=",")
