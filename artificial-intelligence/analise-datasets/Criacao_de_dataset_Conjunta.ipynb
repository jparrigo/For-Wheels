# %%
import pandas as pd
import numpy as np
import difflib
from dataclasses import dataclass

@dataclass()
class FuzzyMerge:
    """
        Works like pandas merge except also merges on approximate matches.
    """
    left: pd.DataFrame
    right: pd.DataFrame
    left_on: str
    right_on: str
    how: str = "inner"
    cutoff: float = 0.3

    def main(self) -> pd.DataFrame:
        temp = self.right.copy()
        temp[self.left_on] = [
            self.get_closest_match(x, self.left[self.left_on]) for x in temp[self.right_on]
        ]

        return self.left.merge(temp, on=self.left_on, how=self.how)

    def get_closest_match(self, left: pd.Series, right: pd.Series) -> str or None:
        matches = difflib.get_close_matches(left, right, cutoff=self.cutoff)

        return matches[0] if matches else None
    
df_car = pd.read_csv("../datasets/cars/cars_dataset.csv", sep=",", header=0)
df_car.drop("Unnamed: 0", axis=1, inplace=True)
df_reviews = pd.read_csv("../datasets/reviews/reviews_dataset.csv", sep=",", header=0)
df_reviews.drop("Unnamed: 0", axis=1, inplace=True)
df_reviews
# Out:
#                        Review_Date Author_Name  \
# 0       on 11/02/15 18:50 PM (PST)         SS
# 1       on 01/17/17 10:49 AM (PST)        Bob
# 2       on 07/31/18 10:58 AM (PDT)      David
# 3       on 02/04/10 09:48 AM (PST)        dan
# 4       on 01/06/10 17:48 PM (PST)     Scotty
# ...                            ...         ...
# 36509   on 03/15/10 02:03 AM (PDT)          D
# 36510   on 03/01/10 19:06 PM (PST)       Paul
# 36511   on 12/19/09 10:41 AM (PST)      Terri
# 36512   on 11/27/09 20:53 PM (PST)      kevin
# 36513   on 12/26/08 15:35 PM (PST)      Colin
#
#                                            Vehicle_Title  \
# 0      2014 Acura RLX Sedan Navigation 4dr Sedan (3.5...
# 1      2017 Acura RLX Sedan Technology Package 4dr Se...
# 2      2018 Acura RLX Hybrid Sport Hybrid SH-AWD 4dr ...
# 3      2006 Acura RSX Hatchback 2dr Hatchback (2.0L 4...
# 4      2006 Acura RSX Hatchback 2dr Hatchback (2.0L 4...
# ...                                                  ...
# 36509  2009 Volvo C30 Hatchback T5 2dr Hatchback (2.5...
# 36510  2009 Volvo C30 Hatchback T5 2dr Hatchback (2.5...
# 36511  2009 Volvo C30 Hatchback T5 2dr Hatchback (2.5...
# 36512  2009 Volvo C30 Hatchback T5 2dr Hatchback (2.5...
# 36513  2009 Volvo C30 Hatchback T5 R-Design 2dr Hatch...
#
#                                             Review_Title  \
# 0      Overall, great car but it does have some problems
# 1                                              Great Car
# 2           Liked the 2014 model and this is even better
# 3                           No more acuras/hondas for me
# 4                                This is no Honda Civic
# ...                                                  ...
# 36509                                   Great little car
# 36510                 Best in Class, Value and Otherwise
# 36511                                         Just Right
# 36512                    Still brings a smile to my face
# 36513                                  One rockin' hatch
#
#                                                   Review  Rating   Make
# 0       I'm very happy with the performance, handling...   3.000  Acura
# 1       Traded in a 2012 Acura TL .  The 2017 Acura R...   5.000  Acura
# 2       Entertainment system may not be intuitive or ...   5.000  Acura
# 3       I bought this car used only to have problems ...   3.000  Acura
# 4       I was pleasantly surprised by the cars handli...   4.125  Acura
# ...                                                  ...     ...    ...
# 36509   We bought a C30 on our return to the US after...   4.750  Volvo
# 36510   Strangely, this exquisite, sophisticated car ...   4.750  Volvo
# 36511   I literally test drove 12 vehicles and kept c...   4.750  Volvo
# 36512   After researching all small hatchbacks in the...   4.125  Volvo
# 36513   Great all-around car, exceptionally well-exec...   4.875  Volvo
#
# [36514 rows x 7 columns]

# %%
df_merged = FuzzyMerge(left=df_reviews, right=df_car, left_on="Vehicle_Title", right_on="Vehicle_Title_Partial").main()
# df_merged = pd.read_csv("datasets/merged_datasets.csv", sep=",", header=0)
# df_merged.drop("Unnamed: 0", axis=1, inplace=True)

# %%
df_merged
# Out:
#                        Review_Date Author_Name  \
# 0       on 07/28/10 07:30 AM (PDT)        Bob
# 1       on 06/21/17 10:47 AM (PDT)        Mac
# 2       on 06/21/17 10:47 AM (PDT)        Mac
# 3       on 06/21/17 10:47 AM (PDT)        Mac
# 4       on 06/21/17 10:47 AM (PDT)        Mac
# ...                            ...         ...
# 14354   on 08/07/10 17:55 PM (PDT)      Chris
# 14355   on 08/07/10 17:55 PM (PDT)      Chris
# 14356   on 08/07/10 17:55 PM (PDT)      Chris
# 14357   on 08/07/10 17:55 PM (PDT)      Chris
# 14358   on 08/07/10 17:55 PM (PDT)      Chris
#
#                                            Vehicle_Title  \
# 0      2010 Acura ZDX Hatchback Advance Package 4dr H...
# 1          2014 Acura RDX SUV 4dr SUV AWD (3.5L 6cyl 6A)
# 2          2014 Acura RDX SUV 4dr SUV AWD (3.5L 6cyl 6A)
# 3          2014 Acura RDX SUV 4dr SUV AWD (3.5L 6cyl 6A)
# 4          2014 Acura RDX SUV 4dr SUV AWD (3.5L 6cyl 6A)
# ...                                                  ...
# 14354  2011 Volvo C30 Hatchback T5 2dr Hatchback (2.5...
# 14355  2011 Volvo C30 Hatchback T5 2dr Hatchback (2.5...
# 14356  2011 Volvo C30 Hatchback T5 2dr Hatchback (2.5...
# 14357  2011 Volvo C30 Hatchback T5 2dr Hatchback (2.5...
# 14358  2011 Volvo C30 Hatchback T5 2dr Hatchback (2.5...
#
#                        Review_Title  \
# 0      This is truly a driver's car
# 1                   Look elsewhere!
# 2                   Look elsewhere!
# 3                   Look elsewhere!
# 4                   Look elsewhere!
# ...                             ...
# 14354         Under-appreciated car
# 14355         Under-appreciated car
# 14356         Under-appreciated car
# 14357         Under-appreciated car
# 14358         Under-appreciated car
#
#                                                   Review  Rating Make_x  \
# 0       I love the fact that with SH-AWD the more gas...   5.000  Acura
# 1       I have had my 2014 RDX for just over a month....   2.000  Acura
# 2       I have had my 2014 RDX for just over a month....   2.000  Acura
# 3       I have had my 2014 RDX for just over a month....   2.000  Acura
# 4       I have had my 2014 RDX for just over a month....   2.000  Acura
# ...                                                  ...     ...    ...
# 14354   A great car for a daily driver. Lots of featu...   4.625  Volvo
# 14355   A great car for a daily driver. Lots of featu...   4.625  Volvo
# 14356   A great car for a daily driver. Lots of featu...   4.625  Volvo
# 14357   A great car for a daily driver. Lots of featu...   4.625  Volvo
# 14358   A great car for a daily driver. Lots of featu...   4.625  Volvo
#
#       Make_y Model  Year  ... Common  Crossover  Exotic Factory Tuner  \
# 0      Acura   ZDX  2013  ...  False       True   False         False
# 1       Audi    Q7  2014  ...  False       True   False         False
# 2       Audi    Q7  2014  ...  False       True   False         False
# 3       Audi    Q7  2014  ...  False       True   False         False
# 4       Audi    Q7  2014  ...  False       True   False         False
# ...      ...   ...   ...  ...    ...        ...     ...           ...
# 14354  Volvo   C30  2011  ...  False      False   False         False
# 14355  Volvo   C30  2012  ...  False      False   False         False
# 14356  Volvo   C30  2012  ...  False      False   False         False
# 14357  Volvo   C30  2013  ...  False      False   False         False
# 14358  Volvo   C30  2013  ...  False      False   False         False
#
#       Hatchback  High-Performance Hybrid Luxury  Performance  \
# 0          True             False  False   True        False
# 1         False             False  False   True        False
# 2         False             False  False   True        False
# 3         False             False  False   True        False
# 4         False             False  False   True        False
# ...         ...               ...    ...    ...          ...
# 14354      True             False  False   True         True
# 14355      True             False  False   True         True
# 14356      True             False  False   True        False
# 14357      True             False  False   True        False
# 14358      True             False  False   True         True
#
#                          Vehicle_Title_Partial
# 0      2013 Acura ZDX 4dr Hatchback AWD (6cyl)
# 1              2014 Audi Q7 4dr SUV AWD (6cyl)
# 2              2014 Audi Q7 4dr SUV AWD (6cyl)
# 3              2014 Audi Q7 4dr SUV AWD (6cyl)
# 4              2014 Audi Q7 4dr SUV AWD (6cyl)
# ...                                        ...
# 14354  2011 Volvo C30 2dr Hatchback FWD (5cyl)
# 14355  2012 Volvo C30 2dr Hatchback FWD (5cyl)
# 14356  2012 Volvo C30 2dr Hatchback FWD (5cyl)
# 14357  2013 Volvo C30 2dr Hatchback FWD (5cyl)
# 14358  2013 Volvo C30 2dr Hatchback FWD (5cyl)
#
# [14359 rows x 32 columns]

# %%
df_merged_worked = df_merged
df_merged_worked = df_merged_worked.where(df_merged_worked["Make_x"].str.upper() == df_merged_worked["Make_y"].str.upper())
df_merged_worked.drop("Make_y", axis=1, inplace=True)
df_merged_worked.rename(columns={"Make_x": "Make"}, inplace=True)
df_merged_worked.drop_duplicates(subset="Review", keep="first", inplace=True)
df_merged_worked = df_merged_worked.dropna(axis=0, how="all")
df_merged_worked = df_merged_worked.reset_index()
df_merged_worked.drop("index", axis=1, inplace=True)

# %%
df_merged_worked = df_merged_worked.astype({"Year": 'int64', "Engine Cylinders": 'int64', "Number of Doors": 'int64', "highway MPG": 'int64', "city mpg": 'int64', "Popularity": 'int64', "MSRP": 'int64'})
df_merged_worked.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1628 entries, 0 to 1627
# Data columns (total 31 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Review_Date            1628 non-null   object
#  1   Author_Name            1628 non-null   object
#  2   Vehicle_Title          1628 non-null   object
#  3   Review_Title           1628 non-null   object
#  4   Review                 1628 non-null   object
#  5   Rating                 1628 non-null   float64
#  6   Make                   1628 non-null   object
#  7   Model                  1628 non-null   object
#  8   Year                   1628 non-null   int64
#  9   Engine Fuel Type       1628 non-null   object
#  10  Engine HP              1609 non-null   float64
#  11  Engine Cylinders       1628 non-null   int64
#  12  Transmission Type      1628 non-null   object
#  13  Driven_Wheels          1628 non-null   object
#  14  Number of Doors        1628 non-null   int64
#  15  Vehicle Size           1628 non-null   object
#  16  Vehicle Style          1628 non-null   object
#  17  highway MPG            1628 non-null   int64
#  18  city mpg               1628 non-null   int64
#  19  Popularity             1628 non-null   int64
#  20  MSRP                   1628 non-null   int64
#  21  Common                 1628 non-null   object
#  22  Crossover              1628 non-null   object
#  23  Exotic                 1628 non-null   object
#  24  Factory Tuner          1628 non-null   object
#  25  Hatchback              1628 non-null   object
#  26  High-Performance       1628 non-null   object
#  27  Hybrid                 1628 non-null   object
#  28  Luxury                 1628 non-null   object
#  29  Performance            1628 non-null   object
#  30  Vehicle_Title_Partial  1628 non-null   object
# dtypes: float64(2), int64(7), object(22)
# memory usage: 394.4+ KB

# %%
df_merged_worked['Make'].value_counts().count()
# Out:
# 41

# %%
df_merged_worked
# Out:
#                       Review_Date Author_Name  \
# 0      on 07/28/10 07:30 AM (PDT)        Bob
# 1      on 09/26/17 10:07 AM (PDT)      Brian
# 2      on 12/26/16 18:08 PM (PST)      Scott
# 3      on 10/18/17 09:25 AM (PDT)       Alex
# 4      on 04/18/18 11:29 AM (PDT)       Lori
# ...                           ...         ...
# 1623   on 09/20/15 18:09 PM (PDT)      scott
# 1624   on 08/22/15 17:39 PM (PDT)      david
# 1625   on 11/07/10 00:00 AM (PDT)         KW
# 1626   on 10/17/10 00:00 AM (PDT)     Lauren
# 1627   on 08/07/10 17:55 PM (PDT)      Chris
#
#                                           Vehicle_Title  \
# 0     2010 Acura ZDX Hatchback Advance Package 4dr H...
# 1         2017 Acura RDX SUV 4dr SUV AWD (3.5L 6cyl 6A)
# 2         2017 Acura RDX SUV 4dr SUV AWD (3.5L 6cyl 6A)
# 3         2018 Acura RDX SUV 4dr SUV AWD (3.5L 6cyl 6A)
# 4         2015 Acura RDX SUV 4dr SUV AWD (3.5L 6cyl 6A)
# ...                                                 ...
# 1623  2015 Volvo XC60 SUV T6 4dr SUV AWD (3.0L 6cyl ...
# 1624  2016 Volvo XC60 SUV T5 4dr SUV AWD (2.5L 5cyl ...
# 1625  2011 Volvo C30 Hatchback T5 2dr Hatchback (2.5...
# 1626  2011 Volvo C30 Hatchback T5 2dr Hatchback (2.5...
# 1627  2011 Volvo C30 Hatchback T5 2dr Hatchback (2.5...
#
#                                            Review_Title  \
# 0                          This is truly a driver's car
# 1                                    Brake System Issue
# 2                                       So far so good.
# 3                                            Nice whip!
# 4                                        Need a button?
# ...                                                 ...
# 1623  UDATED   Goodbye Lexus Rx350 and Hello Volvo XC60
# 1624                                     Updated Review
# 1625                                          Great Car
# 1626                        Forget Mini check out Volvo
# 1627                              Under-appreciated car
#
#                                                  Review  Rating   Make Model  \
# 0      I love the fact that with SH-AWD the more gas...   5.000  Acura   ZDX
# 1      A brake system issue started after 2 weeks of...   1.000  Acura   MDX
# 2      UPDATE 12/27/17 - after owning this car for 1...   4.000  Acura   MDX
# 3      Very smooth driving, almost no road noise. Gr...   5.000  Acura   RDX
# 4      There is no interior or exterior button to au...   3.000  Acura   MDX
# ...                                                 ...     ...    ...   ...
# 1623   Our sticker starts with a T6 AWD, then adds t...   5.000  Volvo  XC60
# 1624   Now at just under 45K Miles and just had insp...   5.000  Volvo  XC60
# 1625   I have had my C30 for two months now and stil...   5.000  Volvo   C30
# 1626   I thought I loved my 2007 Mini S convertible,...   4.875  Volvo   C30
# 1627   A great car for a daily driver. Lots of featu...   4.625  Volvo   C30
#
#       Year Engine Fuel Type  ...  Common  Crossover Exotic Factory Tuner  \
# 0     2013         gasoline  ...   False       True  False         False
# 1     2017         gasoline  ...   False       True  False         False
# 2     2017         gasoline  ...   False       True  False         False
# 3     2016         gasoline  ...   False       True  False         False
# 4     2015         gasoline  ...   False       True  False         False
# ...    ...              ...  ...     ...        ...    ...           ...
# 1623  2015         gasoline  ...   False       True  False         False
# 1624  2016         gasoline  ...   False       True  False         False
# 1625  2011         gasoline  ...   False      False  False         False
# 1626  2011         gasoline  ...   False      False  False         False
# 1627  2011         gasoline  ...   False      False  False         False
#
#       Hatchback High-Performance Hybrid  Luxury  Performance  \
# 0          True            False  False    True        False
# 1         False            False  False    True        False
# 2         False            False  False    True        False
# 3         False            False  False    True        False
# 4         False            False  False    True        False
# ...         ...              ...    ...     ...          ...
# 1623      False            False  False    True         True
# 1624      False            False  False    True        False
# 1625       True            False  False    True        False
# 1626       True            False  False    True        False
# 1627       True            False  False    True        False
#
#                         Vehicle_Title_Partial
# 0     2013 Acura ZDX 4dr Hatchback AWD (6cyl)
# 1           2017 Acura MDX 4dr SUV AWD (6cyl)
# 2           2017 Acura MDX 4dr SUV AWD (6cyl)
# 3           2016 Acura RDX 4dr SUV FWD (6cyl)
# 4           2015 Acura MDX 4dr SUV AWD (6cyl)
# ...                                       ...
# 1623       2015 Volvo XC60 4dr SUV AWD (6cyl)
# 1624       2016 Volvo XC60 4dr SUV AWD (5cyl)
# 1625  2011 Volvo C30 2dr Hatchback FWD (5cyl)
# 1626  2011 Volvo C30 2dr Hatchback FWD (5cyl)
# 1627  2011 Volvo C30 2dr Hatchback FWD (5cyl)
#
# [1628 rows x 31 columns]

# %%
df_merged.to_csv("../datasets/merged_datasets_full.csv", sep=",")
df_merged_worked.to_csv("../datasets/merged_datasets.csv", sep=",")
