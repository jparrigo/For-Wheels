# %%
import pandas as pd
import numpy as np
import difflib
from dataclasses import dataclass

@dataclass()
class FuzzyMerge:
    """
        Works like pandas merge except also merges on approximate matches.
    """
    left: pd.DataFrame
    right: pd.DataFrame
    left_on: str
    right_on: str
    how: str = "inner"
    cutoff: float = 0.3

    def main(self) -> pd.DataFrame:
        temp = self.right.copy()
        temp[self.left_on] = [
            self.get_closest_match(x, self.left[self.left_on]) for x in temp[self.right_on]
        ]

        return self.left.merge(temp, on=self.left_on, how=self.how)

    def get_closest_match(self, left: pd.Series, right: pd.Series) -> str or None:
        matches = difflib.get_close_matches(left, right, cutoff=self.cutoff)

        return matches[0] if matches else None
    
df_car = pd.read_csv("../datasets/cars/cars_dataset.csv", sep=",", header=0)
df_car.drop("Unnamed: 0", axis=1, inplace=True)
df_reviews = pd.read_csv("../datasets/reviews/reviews_dataset.csv", sep=",", header=0)
df_reviews.drop("Unnamed: 0", axis=1, inplace=True)
df_reviews
# Out:
#                        Review_Date Author_Name  \
# 0       on 01/17/17 10:49 AM (PST)        Bob
# 1       on 07/31/18 10:58 AM (PDT)      David
# 2       on 02/04/10 09:48 AM (PST)        dan
# 3       on 08/19/08 12:11 PM (PDT)      David
# 4       on 06/09/08 12:43 PM (PDT)      Keith
# ...                            ...         ...
# 29726   on 03/10/18 14:40 PM (PST)   Jonathan
# 29727   on 03/15/10 02:03 AM (PDT)          D
# 29728   on 03/01/10 19:06 PM (PST)       Paul
# 29729   on 12/19/09 10:41 AM (PST)      Terri
# 29730   on 11/27/09 20:53 PM (PST)      kevin
#
#                                            Vehicle_Title  \
# 0      2017 Acura RLX Sedan Technology Package 4dr Se...
# 1      2018 Acura RLX Hybrid Sport Hybrid SH-AWD 4dr ...
# 2      2006 Acura RSX Hatchback 2dr Hatchback (2.0L 4...
# 3      2006 Acura RSX Hatchback 2dr Hatchback (2.0L 4...
# 4      2006 Acura RSX Hatchback 2dr Hatchback (2.0L 4...
# ...                                                  ...
# 29726  2009 Volvo C30 Hatchback T5 2dr Hatchback (2.5...
# 29727  2009 Volvo C30 Hatchback T5 2dr Hatchback (2.5...
# 29728  2009 Volvo C30 Hatchback T5 2dr Hatchback (2.5...
# 29729  2009 Volvo C30 Hatchback T5 2dr Hatchback (2.5...
# 29730  2009 Volvo C30 Hatchback T5 2dr Hatchback (2.5...
#
#                                        Review_Title  \
# 0                                         Great Car
# 1      Liked the 2014 model and this is even better
# 2                      No more acuras/hondas for me
# 3                                  Great Sports Car
# 4                            Great first sports car
# ...                                             ...
# 29726                                  My 3rd Volvo
# 29727                              Great little car
# 29728            Best in Class, Value and Otherwise
# 29729                                    Just Right
# 29730               Still brings a smile to my face
#
#                                                   Review  Rating   Make
# 0       Traded in a 2012 Acura TL .  The 2017 Acura R...   5.000  Acura
# 1       Entertainment system may not be intuitive or ...   5.000  Acura
# 2       I bought this car used only to have problems ...   3.000  Acura
# 3       This car is great, pretty fast for a 2.0L inl...   4.875  Acura
# 4       This car is great for a first sports car. It ...   4.875  Acura
# ...                                                  ...     ...    ...
# 29726   Sporty, clean lines, well thought out and fun...   5.000  Volvo
# 29727   We bought a C30 on our return to the US after...   4.750  Volvo
# 29728   Strangely, this exquisite, sophisticated car ...   4.750  Volvo
# 29729   I literally test drove 12 vehicles and kept c...   4.750  Volvo
# 29730   After researching all small hatchbacks in the...   4.125  Volvo
#
# [29731 rows x 7 columns]

# %%
df_merged = FuzzyMerge(left=df_reviews, right=df_car, left_on="Vehicle_Title", right_on="Vehicle_Title_Partial").main()
# df_merged = pd.read_csv("datasets/merged_datasets.csv", sep=",", header=0)
# df_merged.drop("Unnamed: 0", axis=1, inplace=True)

# %%
df_merged
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df_merged.where(df_merged["Make_x"] == "McLaren")
#
# NameError: name 'df_merged' is not defined

# %%
df_merged_worked = df_merged
df_merged_worked = df_merged_worked.where(df_merged_worked["Make_x"].str.upper() == df_merged_worked["Make_y"].str.upper())
df_merged_worked.drop("Make_y", axis=1, inplace=True)
df_merged_worked.rename(columns={"Make_x": "Make"}, inplace=True)
df_merged_worked.drop_duplicates(subset="Review", keep="first", inplace=True)
df_merged_worked = df_merged_worked.dropna(axis=0, how="all")
df_merged_worked = df_merged_worked.reset_index()
df_merged_worked.drop("index", axis=1, inplace=True)

# %%
df_merged_worked = df_merged_worked.astype({"Year": 'int64', "Engine Cylinders": 'int64', "Number of Doors": 'int64', "highway MPG": 'int64', "city mpg": 'int64', "Popularity": 'int64', "MSRP": 'int64'})
df_merged_worked.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1461 entries, 0 to 1460
# Data columns (total 31 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Review_Date            1461 non-null   object
#  1   Author_Name            1461 non-null   object
#  2   Vehicle_Title          1461 non-null   object
#  3   Review_Title           1461 non-null   object
#  4   Review                 1461 non-null   object
#  5   Rating                 1461 non-null   float64
#  6   Make                   1461 non-null   object
#  7   Model                  1461 non-null   object
#  8   Year                   1461 non-null   int64
#  9   Engine Fuel Type       1461 non-null   object
#  10  Engine HP              1445 non-null   float64
#  11  Engine Cylinders       1461 non-null   int64
#  12  Transmission Type      1461 non-null   object
#  13  Driven_Wheels          1461 non-null   object
#  14  Number of Doors        1461 non-null   int64
#  15  Vehicle Size           1461 non-null   object
#  16  Vehicle Style          1461 non-null   object
#  17  highway MPG            1461 non-null   int64
#  18  city mpg               1461 non-null   int64
#  19  Popularity             1461 non-null   int64
#  20  MSRP                   1461 non-null   int64
#  21  Common                 1461 non-null   object
#  22  Crossover              1461 non-null   object
#  23  Exotic                 1461 non-null   object
#  24  Factory Tuner          1461 non-null   object
#  25  Hatchback              1461 non-null   object
#  26  High-Performance       1461 non-null   object
#  27  Hybrid                 1461 non-null   object
#  28  Luxury                 1461 non-null   object
#  29  Performance            1461 non-null   object
#  30  Vehicle_Title_Partial  1461 non-null   object
# dtypes: float64(2), int64(7), object(22)
# memory usage: 354.0+ KB

# %%
df_merged_worked
# Out:
#                       Review_Date Author_Name  \
# 0      on 07/28/10 07:30 AM (PDT)        Bob
# 1      on 09/26/17 10:07 AM (PDT)      Brian
# 2      on 12/26/16 18:08 PM (PST)      Scott
# 3      on 10/18/17 09:25 AM (PDT)       Alex
# 4      on 04/18/18 11:29 AM (PDT)       Lori
# ...                           ...         ...
# 1456   on 01/09/10 19:02 PM (PST)       Judy
# 1457   on 09/20/15 18:09 PM (PDT)      scott
# 1458   on 08/22/15 17:39 PM (PDT)      david
# 1459   on 10/17/10 00:00 AM (PDT)     Lauren
# 1460   on 08/07/10 17:55 PM (PDT)      Chris
#
#                                           Vehicle_Title  \
# 0     2010 Acura ZDX Hatchback Advance Package 4dr H...
# 1         2017 Acura RDX SUV 4dr SUV AWD (3.5L 6cyl 6A)
# 2         2017 Acura RDX SUV 4dr SUV AWD (3.5L 6cyl 6A)
# 3         2018 Acura RDX SUV 4dr SUV AWD (3.5L 6cyl 6A)
# 4         2015 Acura RDX SUV 4dr SUV AWD (3.5L 6cyl 6A)
# ...                                                 ...
# 1456  2010 Volvo XC90 SUV V8 4dr SUV AWD (4.4L 8cyl 6A)
# 1457  2015 Volvo XC60 SUV T6 4dr SUV AWD (3.0L 6cyl ...
# 1458  2016 Volvo XC60 SUV T5 4dr SUV AWD (2.5L 5cyl ...
# 1459  2011 Volvo C30 Hatchback T5 2dr Hatchback (2.5...
# 1460  2011 Volvo C30 Hatchback T5 2dr Hatchback (2.5...
#
#                                            Review_Title  \
# 0                          This is truly a driver's car
# 1                                    Brake System Issue
# 2                                       So far so good.
# 3                                            Nice whip!
# 4                                        Need a button?
# ...                                                 ...
# 1456                          XC90 THE BEST OF THE REST
# 1457  UDATED   Goodbye Lexus Rx350 and Hello Volvo XC60
# 1458                                     Updated Review
# 1459                        Forget Mini check out Volvo
# 1460                              Under-appreciated car
#
#                                                  Review  Rating   Make Model  \
# 0      I love the fact that with SH-AWD the more gas...   5.000  Acura   ZDX
# 1      A brake system issue started after 2 weeks of...   1.000  Acura   MDX
# 2      UPDATE 12/27/17 - after owning this car for 1...   4.000  Acura   MDX
# 3      Very smooth driving, almost no road noise. Gr...   5.000  Acura   RDX
# 4      There is no interior or exterior button to au...   3.000  Acura   MDX
# ...                                                 ...     ...    ...   ...
# 1456   I have owned a 2004, 2007, and now own a 2010...   4.875  Volvo  XC60
# 1457   Our sticker starts with a T6 AWD, then adds t...   5.000  Volvo  XC60
# 1458   Now at just under 45K Miles and just had insp...   5.000  Volvo  XC60
# 1459   I thought I loved my 2007 Mini S convertible,...   4.875  Volvo   C30
# 1460   A great car for a daily driver. Lots of featu...   4.625  Volvo   C30
#
#       Year Engine Fuel Type  ...  Common  Crossover Exotic Factory Tuner  \
# 0     2013         gasoline  ...   False       True  False         False
# 1     2017         gasoline  ...   False       True  False         False
# 2     2017         gasoline  ...   False       True  False         False
# 3     2016         gasoline  ...   False       True  False         False
# 4     2015         gasoline  ...   False       True  False         False
# ...    ...              ...  ...     ...        ...    ...           ...
# 1456  2015         gasoline  ...   False       True  False         False
# 1457  2015         gasoline  ...   False       True  False         False
# 1458  2016         gasoline  ...   False       True  False         False
# 1459  2011         gasoline  ...   False      False  False         False
# 1460  2011         gasoline  ...   False      False  False         False
#
#       Hatchback High-Performance Hybrid  Luxury  Performance  \
# 0          True            False  False    True        False
# 1         False            False  False    True        False
# 2         False            False  False    True        False
# 3         False            False  False    True        False
# 4         False            False  False    True        False
# ...         ...              ...    ...     ...          ...
# 1456      False            False  False    True         True
# 1457      False            False  False    True         True
# 1458      False            False  False    True        False
# 1459       True            False  False    True        False
# 1460       True            False  False    True        False
#
#                         Vehicle_Title_Partial
# 0     2013 Acura ZDX 4dr Hatchback AWD (6cyl)
# 1           2017 Acura MDX 4dr SUV AWD (6cyl)
# 2           2017 Acura MDX 4dr SUV AWD (6cyl)
# 3           2016 Acura RDX 4dr SUV FWD (6cyl)
# 4           2015 Acura MDX 4dr SUV AWD (6cyl)
# ...                                       ...
# 1456       2015 Volvo XC60 4dr SUV FWD (4cyl)
# 1457       2015 Volvo XC60 4dr SUV AWD (6cyl)
# 1458       2016 Volvo XC60 4dr SUV AWD (5cyl)
# 1459  2011 Volvo C30 2dr Hatchback FWD (5cyl)
# 1460  2011 Volvo C30 2dr Hatchback FWD (5cyl)
#
# [1461 rows x 31 columns]

# %%
df_merged_worked.to_csv("../datasets/merged_datasets.csv", sep=",")
