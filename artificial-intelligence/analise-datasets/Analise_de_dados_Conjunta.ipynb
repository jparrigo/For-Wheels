# %%
import pandas as pd
import numpy as np
df_merged = pd.read_csv("../datasets/merged_datasets.csv", sep=",", header=0)
df_merged.drop("Unnamed: 0", axis=1, inplace=True)
df_merged.head()
# Out:
#                    Review_Date Author_Name  \
# 0   on 07/28/10 07:30 AM (PDT)        Bob
# 1   on 09/26/17 10:07 AM (PDT)      Brian
# 2   on 12/26/16 18:08 PM (PST)      Scott
# 3   on 10/18/17 09:25 AM (PDT)       Alex
# 4   on 04/18/18 11:29 AM (PDT)       Lori
#
#                                        Vehicle_Title  \
# 0  2010 Acura ZDX Hatchback Advance Package 4dr H...
# 1      2017 Acura RDX SUV 4dr SUV AWD (3.5L 6cyl 6A)
# 2      2017 Acura RDX SUV 4dr SUV AWD (3.5L 6cyl 6A)
# 3      2018 Acura RDX SUV 4dr SUV AWD (3.5L 6cyl 6A)
# 4      2015 Acura RDX SUV 4dr SUV AWD (3.5L 6cyl 6A)
#
#                    Review_Title  \
# 0  This is truly a driver's car
# 1            Brake System Issue
# 2               So far so good.
# 3                    Nice whip!
# 4                Need a button?
#
#                                               Review  Rating   Make Model  \
# 0   I love the fact that with SH-AWD the more gas...     5.0  Acura   ZDX
# 1   A brake system issue started after 2 weeks of...     1.0  Acura   MDX
# 2   UPDATE 12/27/17 - after owning this car for 1...     4.0  Acura   MDX
# 3   Very smooth driving, almost no road noise. Gr...     5.0  Acura   RDX
# 4   There is no interior or exterior button to au...     3.0  Acura   MDX
#
#    Year Engine Fuel Type  ...  Common  Crossover Exotic Factory Tuner  \
# 0  2013         gasoline  ...   False       True  False         False
# 1  2017         gasoline  ...   False       True  False         False
# 2  2017         gasoline  ...   False       True  False         False
# 3  2016         gasoline  ...   False       True  False         False
# 4  2015         gasoline  ...   False       True  False         False
#
#    Hatchback High-Performance Hybrid  Luxury  Performance  \
# 0       True            False  False    True        False
# 1      False            False  False    True        False
# 2      False            False  False    True        False
# 3      False            False  False    True        False
# 4      False            False  False    True        False
#
#                      Vehicle_Title_Partial
# 0  2013 Acura ZDX 4dr Hatchback AWD (6cyl)
# 1        2017 Acura MDX 4dr SUV AWD (6cyl)
# 2        2017 Acura MDX 4dr SUV AWD (6cyl)
# 3        2016 Acura RDX 4dr SUV FWD (6cyl)
# 4        2015 Acura MDX 4dr SUV AWD (6cyl)
#
# [5 rows x 31 columns]

# %%
df_merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1461 entries, 0 to 1460
# Data columns (total 31 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Review_Date            1461 non-null   object
#  1   Author_Name            1461 non-null   object
#  2   Vehicle_Title          1461 non-null   object
#  3   Review_Title           1461 non-null   object
#  4   Review                 1461 non-null   object
#  5   Rating                 1461 non-null   float64
#  6   Make                   1461 non-null   object
#  7   Model                  1461 non-null   object
#  8   Year                   1461 non-null   int64
#  9   Engine Fuel Type       1461 non-null   object
#  10  Engine HP              1445 non-null   float64
#  11  Engine Cylinders       1461 non-null   int64
#  12  Transmission Type      1461 non-null   object
#  13  Driven_Wheels          1461 non-null   object
#  14  Number of Doors        1461 non-null   int64
#  15  Vehicle Size           1461 non-null   object
#  16  Vehicle Style          1461 non-null   object
#  17  highway MPG            1461 non-null   int64
#  18  city mpg               1461 non-null   int64
#  19  Popularity             1461 non-null   int64
#  20  MSRP                   1461 non-null   int64
#  21  Common                 1461 non-null   bool
#  22  Crossover              1461 non-null   bool
#  23  Exotic                 1461 non-null   bool
#  24  Factory Tuner          1461 non-null   bool
#  25  Hatchback              1461 non-null   bool
#  26  High-Performance       1461 non-null   bool
#  27  Hybrid                 1461 non-null   bool
#  28  Luxury                 1461 non-null   bool
#  29  Performance            1461 non-null   bool
#  30  Vehicle_Title_Partial  1461 non-null   object
# dtypes: bool(9), float64(2), int64(7), object(13)
# memory usage: 264.1+ KB

# %%
df_merged["Make"].value_counts()
# Out:
# Make
# Mercedes-Benz    146
# Chevrolet        127
# BMW              108
# Ford             101
# Volkswagen        73
# Toyota            73
# Nissan            68
# Mazda             68
# Lexus             67
# Kia               59
# Honda             48
# Mitsubishi        48
# Hyundai           48
# Dodge             44
# INFINITI          35
# Acura             33
# Volvo             33
# Cadillac          33
# Audi              29
# Subaru            29
# GMC               27
# Porsche           26
# Buick             24
# Chrysler          18
# Land Rover        15
# Lincoln           14
# FIAT               9
# Lotus              8
# Suzuki             8
# Aston Martin       6
# Bentley            6
# Ferrari            6
# Pontiac            5
# Maserati           4
# Rolls-Royce        3
# Maybach            3
# Lamborghini        3
# Tesla              2
# Genesis            2
# Alfa Romeo         1
# HUMMER             1
# Name: count, dtype: int64

# %%
df_merged["Year"].value_counts()
# Out:
# Year
# 2015    424
# 2016    360
# 2017    248
# 2010    135
# 2014    129
# 2011     68
# 2013     49
# 2012     48
# Name: count, dtype: int64

# %%
df_merged["Engine Fuel Type"].value_counts()
# Out:
# Engine Fuel Type
# gasoline     1278
# flex-fuel     103
# electric       52
# diesel         28
# Name: count, dtype: int64

# %%
df_merged["Engine HP"].isna().value_counts()
# Out:
# Engine HP
# False    1445
# True       16
# Name: count, dtype: int64

# %%
df_merged[df_merged["Engine HP"].isna()]
# Out:
#                       Review_Date Author_Name  \
# 441    on 10/15/17 18:01 PM (PDT)       Marc
# 442    on 03/28/16 07:58 AM (PDT)      Shawn
# 748    on 01/13/18 11:26 AM (PST)      Harry
# 753    on 01/12/18 13:57 PM (PST)        Pat
# 754    on 10/22/17 14:06 PM (PDT)       Mark
# 755    on 06/17/17 05:36 AM (PDT)        Don
# 758    on 05/24/16 12:01 PM (PDT)       Tony
# 760    on 12/12/15 17:24 PM (PST)      Brian
# 1117   on 04/05/17 22:03 PM (PDT)       Bill
# 1118   on 08/17/15 22:21 PM (PDT)       Eric
# 1119   on 07/29/15 12:39 PM (PDT)    Michael
# 1174   on 10/02/17 17:57 PM (PDT)       Mike
# 1175   on 06/17/17 05:20 AM (PDT)       Kurt
# 1176   on 08/09/17 13:23 PM (PDT)       mike
# 1280   on 08/03/18 15:36 PM (PDT)       dave
# 1281   on 08/27/16 07:33 AM (PDT)       nick
#
#                                           Vehicle_Title  \
# 441   2017 FIAT 500 Hatchback Pop 2dr Hatchback (1.4...
# 442   2015 FIAT 500 Hatchback Pop 2dr Hatchback (1.4...
# 748      2015 Kia Soul Wagon + 4dr Wagon (2.0L 4cyl 6A)
# 753      2016 Kia Soul Wagon + 4dr Wagon (2.0L 4cyl 6A)
# 754      2016 Kia Soul Wagon + 4dr Wagon (2.0L 4cyl 6A)
# 755      2016 Kia Soul Wagon + 4dr Wagon (2.0L 4cyl 6A)
# 758      2016 Kia Soul Wagon + 4dr Wagon (2.0L 4cyl 6A)
# 760      2016 Kia Soul Wagon + 4dr Wagon (2.0L 4cyl 6A)
# 1117  2014 Mitsubishi Mirage Hatchback DE 4dr Hatchb...
# 1118  2014 Mitsubishi Mirage Hatchback DE 4dr Hatchb...
# 1119  2014 Mitsubishi Mirage Hatchback DE 4dr Hatchb...
# 1174  2015 Nissan Leaf Hatchback S 4dr Hatchback (el...
# 1175  2016 Nissan Leaf Hatchback S 4dr Hatchback (el...
# 1176  2017 Nissan Leaf Hatchback S 4dr Hatchback (el...
# 1280      2018 Tesla Model 3 Sedan 4dr Sedan (electric)
# 1281  2016 Tesla Model S Sedan 70D 4dr Sedan AWD (el...
#
#                                            Review_Title  \
# 441                          As good as my GTI Autobahn
# 442   Give this car a chance, you won't be dissapointed
# 748                                       Used KIA Soul
# 753                                   My Little Red Box
# 754                                   Love my 2016 Soul
# 755                   One of the best cars I have owned
# 758                                       Love my Soul!
# 760                    Kia has officially blown me away
# 1117                                      Buy this car!
# 1118            A modern take on the original VW beetle
# 1119  Great economy car, but should have recall issued.
# 1174             Bought used 2015 for $9300 and love it
# 1175                      Best car to own for commuting
# 1176  space ship 14 months of ownership/ gettin better.
# 1280                                 Driving the Future
# 1281                                 improvement needed
#
#                                                  Review  Rating        Make  \
# 441    Car is wonderful, as much fun as any car I've...     5.0        FIAT
# 442    The big deal with these cars are the value fo...     5.0        FIAT
# 748    I would not buy this car New. I bought a used...     4.0         Kia
# 753    After owning a bigger orange box (Honda Eleme...     4.0         Kia
# 754    I have always bought luxury cars and SUV's . ...     5.0         Kia
# 755            Real good quality and very good handling     4.0         Kia
# 758    Kia has done a great job with the Soul. Espec...     5.0         Kia
# 760    Let me preface this review with the fact that...     5.0         Kia
# 1117   I bought my 2014 Mirage in 2015 with 7200 mil...     5.0  Mitsubishi
# 1118   I have owned this car for just over a year no...     5.0  Mitsubishi
# 1119   Love this car, and it's decently quick with a...     3.0  Mitsubishi
# 1174   I have been looking at the Leaf for several m...     5.0      Nissan
# 1175   This car is great. I like having the filling ...     5.0      Nissan
# 1176   The worst thing about this vehicle is resale ...     5.0      Nissan
# 1280   Sold my C series MB to purchase this car.  As...     5.0       Tesla
# 1281   no storage, 2 poorly placed cup holders, hard...     3.0       Tesla
#
#         Model  Year Engine Fuel Type  ...  Common  Crossover Exotic  \
# 441      500e  2016         electric  ...   False      False  False
# 442      500e  2015         electric  ...   False      False  False
# 748   Soul EV  2015         electric  ...    True      False  False
# 753   Soul EV  2016         electric  ...    True      False  False
# 754   Soul EV  2016         electric  ...    True      False  False
# 755   Soul EV  2016         electric  ...    True      False  False
# 758   Soul EV  2016         electric  ...    True      False  False
# 760   Soul EV  2016         electric  ...    True      False  False
# 1117   i-MiEV  2014         electric  ...   False      False  False
# 1118   i-MiEV  2014         electric  ...   False      False  False
# 1119   i-MiEV  2014         electric  ...   False      False  False
# 1174     Leaf  2015         electric  ...   False      False  False
# 1175     Leaf  2016         electric  ...   False      False  False
# 1176     Leaf  2014         electric  ...   False      False  False
# 1280  Model S  2014         electric  ...   False      False   True
# 1281  Model S  2016         electric  ...   False      False   True
#
#      Factory Tuner  Hatchback High-Performance Hybrid  Luxury  Performance  \
# 441          False       True            False  False   False        False
# 442          False       True            False  False   False        False
# 748          False      False            False  False   False        False
# 753          False      False            False  False   False        False
# 754          False      False            False  False   False        False
# 755          False      False            False  False   False        False
# 758          False      False            False  False   False        False
# 760          False      False            False  False   False        False
# 1117         False       True            False  False   False        False
# 1118         False       True            False  False   False        False
# 1119         False       True            False  False   False        False
# 1174         False       True            False  False   False        False
# 1175         False       True            False  False   False        False
# 1176         False       True            False  False   False        False
# 1280         False      False             True  False   False        False
# 1281         False      False            False  False   False         True
#
#                                 Vehicle_Title_Partial
# 441           2016 FIAT 500e 2dr Hatchback FWD (0cyl)
# 442           2015 FIAT 500e 2dr Hatchback FWD (0cyl)
# 748             2015 Kia Soul EV 4dr Wagon FWD (0cyl)
# 753             2016 Kia Soul EV 4dr Wagon FWD (0cyl)
# 754             2016 Kia Soul EV 4dr Wagon FWD (0cyl)
# 755             2016 Kia Soul EV 4dr Wagon FWD (0cyl)
# 758             2016 Kia Soul EV 4dr Wagon FWD (0cyl)
# 760             2016 Kia Soul EV 4dr Wagon FWD (0cyl)
# 1117  2014 Mitsubishi i-MiEV 4dr Hatchback RWD (0cyl)
# 1118  2014 Mitsubishi i-MiEV 4dr Hatchback RWD (0cyl)
# 1119  2014 Mitsubishi i-MiEV 4dr Hatchback RWD (0cyl)
# 1174        2015 Nissan Leaf 4dr Hatchback FWD (0cyl)
# 1175        2016 Nissan Leaf 4dr Hatchback FWD (0cyl)
# 1176        2014 Nissan Leaf 4dr Hatchback FWD (0cyl)
# 1280          2014 Tesla Model S 4dr Sedan RWD (0cyl)
# 1281          2016 Tesla Model S 4dr Sedan AWD (0cyl)
#
# [16 rows x 31 columns]

# %%
df_merged["Engine HP"].min()
# Out:
# 66.0

# %%
df_merged["Engine HP"].max()
# Out:
# 750.0

# %%
df_merged["Engine Cylinders"].value_counts()
# Out:
# Engine Cylinders
# 4     641
# 6     463
# 8     239
# 0      53
# 5      36
# 12     22
# 3       4
# 10      3
# Name: count, dtype: int64

# %%
df_merged["Transmission Type"].value_counts()
# Out:
# Transmission Type
# AUTOMATIC           1102
# MANUAL               226
# AUTOMATED_MANUAL      81
# DIRECT_DRIVE          52
# Name: count, dtype: int64

# %%
df_merged["Driven_Wheels"].value_counts()
# Out:
# Driven_Wheels
# FWD    618
# AWD    406
# RWD    336
# 4WD    101
# Name: count, dtype: int64

# %%
df_merged["Number of Doors"].value_counts()
# Out:
# Number of Doors
# 4    1145
# 2     316
# Name: count, dtype: int64

# %%
df_merged["Vehicle Size"].value_counts()
# Out:
# Vehicle Size
# Midsize    600
# Compact    577
# Large      284
# Name: count, dtype: int64

# %%
df_merged["Vehicle Style"].value_counts()
# Out:
# Vehicle Style
# Sedan          427
# SUV            369
# Hatchback      204
# Coupe          128
# Convertible    126
# Pickup         101
# Wagon           74
# Minivan         32
# Name: count, dtype: int64
