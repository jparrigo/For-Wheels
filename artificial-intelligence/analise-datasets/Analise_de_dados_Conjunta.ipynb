# %%
import pandas as pd
import numpy as np

df_merged = pd.read_csv("../datasets/combined/merged_datasets.csv", sep=",", header=0)
df_merged.drop("Unnamed: 0", axis=1, inplace=True)
df_merged.head()
# Out:
#                    Review_Date Author_Name  \
# 0   on 07/28/10 07:30 AM (PDT)        Bob
# 1   on 09/26/17 10:07 AM (PDT)      Brian
# 2   on 12/26/16 18:08 PM (PST)      Scott
# 3   on 10/18/17 09:25 AM (PDT)       Alex
# 4   on 04/18/18 11:29 AM (PDT)       Lori
#
#                                        Vehicle_Title  \
# 0  2010 Acura ZDX Hatchback Advance Package 4dr H...
# 1      2017 Acura RDX SUV 4dr SUV AWD (3.5L 6cyl 6A)
# 2      2017 Acura RDX SUV 4dr SUV AWD (3.5L 6cyl 6A)
# 3      2018 Acura RDX SUV 4dr SUV AWD (3.5L 6cyl 6A)
# 4      2015 Acura RDX SUV 4dr SUV AWD (3.5L 6cyl 6A)
#
#                    Review_Title  \
# 0  This is truly a driver's car
# 1            Brake System Issue
# 2               So far so good.
# 3                    Nice whip!
# 4                Need a button?
#
#                                               Review  Rating   Make Model  \
# 0   I love the fact that with SH-AWD the more gas...     5.0  Acura   ZDX
# ...

# %%
df_merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1628 entries, 0 to 1627
# Data columns (total 31 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Review_Date            1628 non-null   object
#  1   Author_Name            1628 non-null   object
#  2   Vehicle_Title          1628 non-null   object
#  3   Review_Title           1628 non-null   object
#  4   Review                 1628 non-null   object
#  5   Rating                 1628 non-null   float64
#  6   Make                   1628 non-null   object
#  7   Model                  1628 non-null   object
#  8   Year                   1628 non-null   int64
#  9   Engine Fuel Type       1628 non-null   object
#  10  Engine HP              1609 non-null   float64
#  11  Engine Cylinders       1628 non-null   int64
#  12  Transmission Type      1628 non-null   object
#  13  Driven_Wheels          1628 non-null   object
# ...

# %%
df_merged["Make"].value_counts()
# Out:
# Make
# Chevrolet        149
# Mercedes-Benz    144
# BMW              125
# Ford             112
# Lexus             84
# Toyota            82
# Nissan            80
# Mazda             80
# Kia               69
# Volkswagen        67
# Mitsubishi        52
# Honda             51
# Hyundai           51
# Dodge             50
# INFINITI          41
# Volvo             41
# Audi              38
# Acura             37
# GMC               33
# Porsche           32
# Subaru            30
# Buick             24
# Cadillac          21
# Chrysler          21
# Lincoln           16
# Land Rover        16
# FIAT              12
# Lotus             11
# Suzuki            11
# Aston Martin       8
# Bentley            7
# Maserati           6
# Ferrari            5
# Rolls-Royce        4
# Lamborghini        4
# Pontiac            4
# Maybach            3
# Genesis            3
# Tesla              2
# HUMMER             1
# Alfa Romeo         1
# Name: count, dtype: int64

# %%
df_merged["Year"].value_counts()
# Out:
# Year
# 2015    464
# 2016    431
# 2017    265
# 2010    152
# 2014    136
# 2011     75
# 2012     54
# 2013     51
# Name: count, dtype: int64

# %%
df_merged["Engine Fuel Type"].value_counts()
# Out:
# Engine Fuel Type
# gasoline     1436
# flex-fuel     118
# electric       41
# diesel         33
# Name: count, dtype: int64

# %%
df_merged["Engine HP"].isna().value_counts()
# Out:
# Engine HP
# False    1609
# True       19
# Name: count, dtype: int64

# %%
df_merged[df_merged["Engine HP"].isna()]
# Out:
#                       Review_Date Author_Name  \
# 494    on 10/15/17 18:01 PM (PDT)       Marc
# 495    on 04/22/17 20:23 PM (PDT)    Vanessa
# 496    on 03/28/16 07:58 AM (PDT)      Shawn
# 838    on 01/13/18 11:26 AM (PST)      Harry
# 840    on 01/30/17 16:04 PM (PST)    Douglas
# 841    on 08/10/15 16:23 PM (PDT)      Dylan
# 845    on 01/12/18 13:57 PM (PST)        Pat
# 846    on 10/22/17 14:06 PM (PDT)       Mark
# 847    on 06/17/17 05:36 AM (PDT)        Don
# 850    on 05/24/16 12:01 PM (PDT)       Tony
# 853    on 12/12/15 17:24 PM (PST)      Brian
# 1250   on 04/05/17 22:03 PM (PDT)       Bill
# 1251   on 08/17/15 22:21 PM (PDT)       Eric
# 1252   on 07/29/15 12:39 PM (PDT)    Michael
# 1317   on 10/02/17 17:57 PM (PDT)       Mike
# 1318   on 06/17/17 05:20 AM (PDT)       Kurt
# 1319   on 08/09/17 13:23 PM (PDT)       mike
# 1436   on 08/03/18 15:36 PM (PDT)       dave
# 1437   on 08/27/16 07:33 AM (PDT)       nick
#
# ...

# %%
df_merged["Engine HP"].min()
# Out:
# 66.0

# %%
df_merged["Engine HP"].max()
# Out:
# 750.0

# %%
df_merged["Engine Cylinders"].value_counts()
# Out:
# Engine Cylinders
# 4     732
# 6     533
# 8     258
# 0      42
# 5      29
# 12     25
# 3       5
# 10      4
# Name: count, dtype: int64

# %%
df_merged["Transmission Type"].value_counts()
# Out:
# Transmission Type
# AUTOMATIC           1228
# MANUAL               265
# AUTOMATED_MANUAL      94
# DIRECT_DRIVE          41
# Name: count, dtype: int64

# %%
df_merged["Driven_Wheels"].value_counts()
# Out:
# Driven_Wheels
# FWD    668
# AWD    465
# RWD    387
# 4WD    108
# Name: count, dtype: int64

# %%
df_merged["Number of Doors"].value_counts()
# Out:
# Number of Doors
# 4    1293
# 2     335
# Name: count, dtype: int64

# %%
df_merged["Vehicle Size"].value_counts()
# Out:
# Vehicle Size
# Midsize    705
# Compact    617
# Large      306
# Name: count, dtype: int64

# %%
df_merged["Vehicle Style"].value_counts()
# Out:
# Vehicle Style
# Sedan          502
# SUV            412
# Hatchback      210
# Coupe          149
# Convertible    117
# Pickup         113
# Wagon           90
# Minivan         35
# Name: count, dtype: int64
